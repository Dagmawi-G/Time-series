# %%
import pandas as pd
from pathlib import Path

# Define events
events_data = [
    {"Event_Date": "01-Jan-12", "Event": "Arab Spring unrest", "Category": "Geopolitical"},
    {"Event_Date": "01-Nov-14", "Event": "OPEC decides not to cut production", "Category": "Economic"},
    {"Event_Date": "01-Mar-20", "Event": "COVID-19 pandemic begins", "Category": "Global"},
    {"Event_Date": "24-Feb-22", "Event": "Russia-Ukraine conflict begins", "Category": "Geopolitical"},
]
df_events = pd.DataFrame(events_data)
df_events['Date'] = pd.to_datetime(df_events['Event_Date'], format='%d-%b-%y')
output_path = Path("C:/Users/IE/Desktop/Week 10/data/events.csv")
df_events.to_csv(output_path, index=False)
print(f"Created events.csv at {output_path}")
# Out:
# Created events.csv at C:\Users\IE\Desktop\Week 10\data\processed\events.csv
